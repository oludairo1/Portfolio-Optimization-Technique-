# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Stocks = pd.read_csv('C:/Users/Oludairo Omokorede/Downloads/Mutual_Funds_Sht_list20.csv',index_col= 'Date')

# %%
Stocks.head()
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# Date
# 4/17/2020             16.6991             112.35             2.5766
# 4/24/2020             16.8738             112.35             2.5808
# 05/01/2020            16.6996             112.33             2.5811
# 05/08/2020            16.8233             112.33             2.5871
# 5/15/2020             16.9853             112.33             2.5927
#
#             CCASLTF MK Equity  BBFTOP3 KY Equity  CRLCBUU LX Equity  \
# Date
# 4/17/2020              3.3116            1275.83              10.69
# 4/24/2020              3.3167            1276.46              10.69
# 05/01/2020             3.3174            1276.78              10.68
# 05/08/2020             3.3203            1278.59              10.71
# 5/15/2020              3.3325            1279.82              10.68
#
#             BCUSDLF KK Equity  BLUESPH BM Equity  PFGLAAU LX Equity  \
# Date
# 4/17/2020               10.76            1076.21             114.32
# 4/24/2020               10.77            1076.21             114.32
# 05/01/2020              10.77            1087.01             114.97
# 05/08/2020              10.77            1087.01             114.97
# 5/15/2020               10.78            1087.01             115.36
#
#             ALPCRDA LX Equity  BUTIBLI KY Equity  SCHGTRA LX Equity
# Date
# 4/17/2020              116.33              29.97           107.9620
# 4/24/2020              117.05              29.32           107.9444
# 05/01/2020             116.80              30.00           108.6293
# 05/08/2020             116.74              29.84           108.6894
# 5/15/2020              117.38              29.95           108.4216

# %%
Stocks.tail()
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# Date
# 1/14/2022             22.6119             116.57             2.9513
# 1/21/2022             22.5163             116.57             2.9610
# 1/28/2022             22.5308             116.57             2.9577
# 02/04/2022            22.6486             116.57             2.9558
# 02/11/2022            22.5737             116.57             2.9707
#
#             CCASLTF MK Equity  BBFTOP3 KY Equity  CRLCBUU LX Equity  \
# Date
# 1/14/2022              3.7834            1417.68              11.63
# 1/21/2022              3.7951            1421.01              11.64
# 1/28/2022              3.7931            1421.72              11.65
# 02/04/2022             3.7901            1421.81              11.66
# 02/11/2022             3.8039            1421.87              11.65
#
#             BCUSDLF KK Equity  BLUESPH BM Equity  PFGLAAU LX Equity  \
# Date
# 1/14/2022                10.9            1200.45             135.89
# 1/21/2022                10.9            1200.45             134.86
# 1/28/2022                10.9            1200.45             134.86
# 02/04/2022               10.9            1192.33             134.86
# 02/11/2022               10.9            1192.33             134.86
#
#             ALPCRDA LX Equity  BUTIBLI KY Equity  SCHGTRA LX Equity
# Date
# 1/14/2022              138.56              39.40           129.6124
# 1/21/2022              138.40              38.81           128.4681
# 1/28/2022              138.23              37.83           126.8428
# 02/04/2022             137.75              38.56           127.9764
# 02/11/2022             137.62              38.40           128.1968

# %%
Stocks.plot(figsize=(10, 7))
plt.title("Closing Price of Mutual Funds", fontsize=16)
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %%
Ret= Stocks.pct_change().apply(lambda x: np.log(1+x))
Ret.head()
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# Date
# 4/17/2020                 NaN                NaN                NaN
# 4/24/2020            0.010407           0.000000           0.001629
# 05/01/2020          -0.010377          -0.000178           0.000116
# 05/08/2020           0.007380           0.000000           0.002322
# 5/15/2020            0.009583           0.000000           0.002162
#
#             CCASLTF MK Equity  BBFTOP3 KY Equity  CRLCBUU LX Equity  \
# Date
# 4/17/2020                 NaN                NaN                NaN
# 4/24/2020            0.001539           0.000494           0.000000
# 05/01/2020           0.000211           0.000251          -0.000936
# 05/08/2020           0.000874           0.001417           0.002805
# 5/15/2020            0.003668           0.000962          -0.002805
#
#             BCUSDLF KK Equity  BLUESPH BM Equity  PFGLAAU LX Equity  \
# Date
# 4/17/2020                 NaN                NaN                NaN
# 4/24/2020            0.000929           0.000000           0.000000
# 05/01/2020           0.000000           0.009985           0.005670
# 05/08/2020           0.000000           0.000000           0.000000
# 5/15/2020            0.000928           0.000000           0.003386
#
#             ALPCRDA LX Equity  BUTIBLI KY Equity  SCHGTRA LX Equity
# Date
# 4/17/2020                 NaN                NaN                NaN
# 4/24/2020            0.006170          -0.021927          -0.000163
# 05/01/2020          -0.002138           0.022928           0.006325
# 05/08/2020          -0.000514          -0.005348           0.000553
# 5/15/2020            0.005467           0.003680          -0.002467

# %%
Ret.tail()
# Out:
#             AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# Date
# 1/14/2022            0.016364                0.0           0.003360
# 1/21/2022           -0.004237                0.0           0.003281
# 1/28/2022            0.000644                0.0          -0.001115
# 02/04/2022           0.005215                0.0          -0.000643
# 02/11/2022          -0.003313                0.0           0.005028
#
#             CCASLTF MK Equity  BBFTOP3 KY Equity  CRLCBUU LX Equity  \
# Date
# 1/14/2022            0.002276           0.000953          -0.000859
# 1/21/2022            0.003088           0.002346           0.000859
# 1/28/2022           -0.000527           0.000500           0.000859
# 02/04/2022          -0.000791           0.000063           0.000858
# 02/11/2022           0.003634           0.000042          -0.000858
#
#             BCUSDLF KK Equity  BLUESPH BM Equity  PFGLAAU LX Equity  \
# Date
# 1/14/2022                 0.0           0.000000           0.000000
# 1/21/2022                 0.0           0.000000          -0.007609
# 1/28/2022                 0.0           0.000000           0.000000
# 02/04/2022                0.0          -0.006787           0.000000
# 02/11/2022                0.0           0.000000           0.000000
#
#             ALPCRDA LX Equity  BUTIBLI KY Equity  SCHGTRA LX Equity
# Date
# 1/14/2022           -0.000289          -0.005821           0.001005
# 1/21/2022           -0.001155          -0.015088          -0.008868
# 1/28/2022           -0.001229          -0.025576          -0.012732
# 02/04/2022          -0.003479           0.019113           0.008897
# 02/11/2022          -0.000944          -0.004158           0.001721

# %%
Ret.plot(title='Stocks weekly returns',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Stocks weekly returns'}, xlabel='Date'>

# %%
Ann_Ret = Ret.mean()*52
print (Ann_Ret)
# Out:
# AIBALMA AB Equity    0.164994
# LODFUIA LX Equity    0.020183
# CCASORI MK Equity    0.077905
# CCASLTF MK Equity    0.075863
# BBFTOP3 KY Equity    0.059322
# CRLCBUU LX Equity    0.047072
# BCUSDLF KK Equity    0.007076
# BLUESPH BM Equity    0.056085
# PFGLAAU LX Equity    0.090445
# ALPCRDA LX Equity    0.091994
# BUTIBLI KY Equity    0.135671
# SCHGTRA LX Equity    0.094031
# dtype: float64

# %%
Ann_Risk = Ret.std()*(52)**(0.5)
print(Ann_Risk)
# Out:
# AIBALMA AB Equity    0.052010
# LODFUIA LX Equity    0.006843
# CCASORI MK Equity    0.016388
# CCASLTF MK Equity    0.016577
# BBFTOP3 KY Equity    0.011316
# CRLCBUU LX Equity    0.017065
# BCUSDLF KK Equity    0.002373
# BLUESPH BM Equity    0.046774
# PFGLAAU LX Equity    0.039963
# ALPCRDA LX Equity    0.027841
# BUTIBLI KY Equity    0.080982
# SCHGTRA LX Equity    0.046193
# dtype: float64

# %%
Ret_Risk = (Ann_Ret/Ann_Risk)
print (Ret_Risk)    #sharpe ratio you have to maximizse
# Out:
# AIBALMA AB Equity    3.172365
# LODFUIA LX Equity    2.949239
# CCASORI MK Equity    4.753824
# CCASLTF MK Equity    4.576345
# BBFTOP3 KY Equity    5.242223
# CRLCBUU LX Equity    2.758347
# BCUSDLF KK Equity    2.982097
# BLUESPH BM Equity    1.199068
# PFGLAAU LX Equity    2.263234
# ALPCRDA LX Equity    3.304219
# BUTIBLI KY Equity    1.675332
# SCHGTRA LX Equity    2.035596
# dtype: float64

# %%
x=Ann_Risk
y=Ann_Ret
plt.scatter(x,y)
plt.show()

# %%
Ret_Corr = Ret.corr()
print(Ret_Corr)
# Out:
#                    AIBALMA AB Equity  LODFUIA LX Equity  CCASORI MK Equity  \
# AIBALMA AB Equity           1.000000           0.057520           0.272233
# LODFUIA LX Equity           0.057520           1.000000          -0.356253
# CCASORI MK Equity           0.272233          -0.356253           1.000000
# CCASLTF MK Equity           0.184235          -0.257593           0.611575
# BBFTOP3 KY Equity          -0.000618           0.147011           0.012781
# CRLCBUU LX Equity           0.016609          -0.109779           0.089729
# BCUSDLF KK Equity           0.118154          -0.062763           0.025011
# BLUESPH BM Equity          -0.031434           0.173652          -0.130214
# PFGLAAU LX Equity           0.002947          -0.057284           0.021940
# ALPCRDA LX Equity           0.193055          -0.003831          -0.012737
# BUTIBLI KY Equity           0.209127           0.060482           0.040790
# SCHGTRA LX Equity           0.453203          -0.077659           0.421540
#
#                    CCASLTF MK Equity  BBFTOP3 KY Equity  CRLCBUU LX Equity  \
# AIBALMA AB Equity           0.184235          -0.000618           0.016609
# LODFUIA LX Equity          -0.257593           0.147011          -0.109779
# CCASORI MK Equity           0.611575           0.012781           0.089729
# CCASLTF MK Equity           1.000000          -0.120390           0.060093
# BBFTOP3 KY Equity          -0.120390           1.000000           0.104455
# CRLCBUU LX Equity           0.060093           0.104455           1.000000
# BCUSDLF KK Equity           0.077700          -0.038099           0.033390
# BLUESPH BM Equity          -0.053352           0.067465          -0.135009
port_var = Ret_Covar.mul(w, axis=0).mul(w, axis=1).sum().sum()
Ann_port_std = (port_var*52)**(0.5)
print (port_var)
print (port_var*52)
# Out:
# 4.560960787997911e-06
# 0.00023716996097589136

# %%
Ann_port_std
# Out:
# 0.015400323404912358

# %%
w = [1/len(Stocks.columns)]*len(Stocks.columns)
port_er = (w*Ann_Ret).sum()
port_er   #equally weighted port
# Out:
# 0.07672003230854617

# %%
assets = pd.concat([Ann_Ret,Ann_Risk,Ret_Risk], axis=1)
assets.columns = ['Ann Returns', 'Ann Risk', 'Return Risk Ratio']
assets
# Out:
#                    Ann Returns  Ann Risk  Return Risk Ratio
# AIBALMA AB Equity     0.164994  0.052010           3.172365
# LODFUIA LX Equity     0.020183  0.006843           2.949239
# CCASORI MK Equity     0.077905  0.016388           4.753824
# CCASLTF MK Equity     0.075863  0.016577           4.576345
# BBFTOP3 KY Equity     0.059322  0.011316           5.242223
# CRLCBUU LX Equity     0.047072  0.017065           2.758347
# BCUSDLF KK Equity     0.007076  0.002373           2.982097
# BLUESPH BM Equity     0.056085  0.046774           1.199068
# PFGLAAU LX Equity     0.090445  0.039963           2.263234
# ALPCRDA LX Equity     0.091994  0.027841           3.304219
# BUTIBLI KY Equity     0.135671  0.080982           1.675332
# SCHGTRA LX Equity     0.094031  0.046193           2.035596

# %%
import matplotlib.pyplot as plt
x = Ann_Risk 
y = Ann_Ret
plt.scatter(x, y)
plt.show()

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(Stocks.columns)
num_portfolios = 5000

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(Stocks.columns)
num_portfolios = 5000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights,Ann_Ret) 
    p_ret.append(returns)
    var = Ret_Covar.mul(weights, axis=0).mul(weights, axis=1).sum().sum() # Portfolio Variance
    sd = np.sqrt(var) #Daily standard deviation
    ann_sd = sd*np.sqrt(52) #Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Risk':p_vol}
for counter, symbol in enumerate(Stocks.columns.tolist()):
#print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]
portfolios = pd.DataFrame(data)
portfolios.head()
# Out:
#     Returns      Risk  AIBALMA AB Equity weight  LODFUIA LX Equity weight  \
# 0  0.072252  0.018058                  0.061897                  0.063606
# 1  0.074128  0.017698                  0.030219                  0.045570
# 2  0.065581  0.016492                  0.042368                  0.074581
# 3  0.073810  0.017243                  0.027085                  0.012352
# 4  0.070155  0.014679                  0.090884                  0.029612
#
#    CCASORI MK Equity weight  CCASLTF MK Equity weight  \
# 0                  0.079059                  0.023291
# 1                  0.017959                  0.073874
# 2                  0.000943                  0.052149
# 3                  0.097130                  0.142235
# 4                  0.050546                  0.116590
#
#    BBFTOP3 KY Equity weight  CRLCBUU LX Equity weight  \
# 0                  0.171872                  0.019826
# 1                  0.162556                  0.127004
# 2                  0.169356                  0.004057
# 3                  0.157880                  0.034795
# 4                  0.171682                  0.035686
#
#    BCUSDLF KK Equity weight  BLUESPH BM Equity weight  \
# 0                  0.198842                  0.043976
# 1                  0.053606                  0.159190
# 2                  0.230546                  0.118597
# 3                  0.088333                  0.184191
# 4                  0.172344                  0.157949
#
#    PFGLAAU LX Equity weight  ALPCRDA LX Equity weight  \
# 0                  0.024260                  0.038431
# 1                  0.057700                  0.079229
# 2                  0.009457                  0.148341
# 3                  0.040633                  0.023945
# 4                  0.039342                  0.005007
#
#    BUTIBLI KY Equity weight  SCHGTRA LX Equity weight
# 0                  0.149959                  0.124981
# 1                  0.135113                  0.057979
# 2                  0.143269                  0.006336
# 3                  0.117630                  0.073790
# 4                  0.085502                  0.044856

# %%
portfolios.plot.scatter(x='Risk', y='Returns', marker='o', s=17, alpha=0.3, grid=True, figsize=[7,5])
# Out:
# <AxesSubplot:xlabel='Risk', ylabel='Returns'>

# %%
min_vol_port = portfolios.iloc[portfolios['Risk'].idxmin()]
# idxmin() gives us the minimum value in the column specified.
min_vol_port #mini value
# Out:
# Returns                     0.056146
# Risk                        0.007220
# AIBALMA AB Equity weight    0.006295
# LODFUIA LX Equity weight    0.121501
# CCASORI MK Equity weight    0.019706
# CCASLTF MK Equity weight    0.182210
# BBFTOP3 KY Equity weight    0.176586
# CRLCBUU LX Equity weight    0.187296
# BCUSDLF KK Equity weight    0.121077
# BLUESPH BM Equity weight    0.026108
# PFGLAAU LX Equity weight    0.020402
# ALPCRDA LX Equity weight    0.085528
# BUTIBLI KY Equity weight    0.023049
# SCHGTRA LX Equity weight    0.030242
# Name: 4988, dtype: float64

# %%
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=200)

# %%
# Finding the optimal portfolio
rf = 0.01 # risk factor
optimal_risky_port = portfolios.iloc[((portfolios['Returns']-rf)/portfolios['Risk']).idxmax()]
optimal_risky_port
# Out:
# Returns                     0.056146
# Risk                        0.007220
# AIBALMA AB Equity weight    0.006295
# LODFUIA LX Equity weight    0.121501
# CCASORI MK Equity weight    0.019706
# CCASLTF MK Equity weight    0.182210
# BBFTOP3 KY Equity weight    0.176586
# CRLCBUU LX Equity weight    0.187296
# BCUSDLF KK Equity weight    0.121077
# BLUESPH BM Equity weight    0.026108
# PFGLAAU LX Equity weight    0.020402
# ALPCRDA LX Equity weight    0.085528
# BUTIBLI KY Equity weight    0.023049
# SCHGTRA LX Equity weight    0.030242
# Name: 4988, dtype: float64

# %%
plt.subplots(figsize=(7, 5))
plt.scatter(portfolios['Risk'], portfolios['Returns'],marker='o', s=10, alpha=0.3)
plt.scatter(min_vol_port[1], min_vol_port[0], color='r', marker='*', s=500)
plt.scatter(optimal_risky_port[1], optimal_risky_port[0], color='g', marker='*', s=500)
